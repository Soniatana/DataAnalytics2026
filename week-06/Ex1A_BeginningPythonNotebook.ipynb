# %%
name = "Sonia"
print("Hello", name)
# Out:
# Hello Sonia

# %%
age = 24
print("I am", age, "years old")
# Out:
# I am 24 years old

# %%
movies = ["Titanic", "Avatar", "Black Panther"]

print(movies)
print(len(movies))s
